# %%
import numpy as np
import mne
import matplotlib.pyplot as plt
import scipy
# %matplotlib  inline

mne.set_log_level('WARNING')

x=mne.io.read_epochs_eeglab('G:\\a Skripsie\\a Data\\18-08-22 - Neele\\Preprocessed Data\\ICA\\Neele T1 epoch.set')
y=mne.io.read_epochs_eeglab('G:\\a Skripsie\\a Data\\18-08-22 - Neele\\Preprocessed Data\\ICA\\Neele T1 epoch.set')

#event=mne.find_events()
'''    print(ep)
    print(ep[59][2499])
    print(i)
    i=i+1
print(ep[59][2499])


print("Normal ep")
print(ep)
print("Flat ep")

ep.flatten()

len(ep.flatten())
#print(ep[59][2499])'''
i=0
for ep in x:
    i=i+1
    print(i)
    j = ep.flatten()
    print(j)
    print(len(j))
# Out:
# 1
# [  2.89373951e-05   2.74318886e-05   2.58662701e-05 ...,  -2.28625450e-05
#   -2.31678581e-05  -2.67009125e-05]
# 150000
# 2
# [ -2.28281808e-06  -1.71923459e-06  -3.18983293e-06 ...,   2.09340954e-05
#    1.54457073e-05   1.05399303e-05]
# 150000
# 3
# [ -3.58838463e-05  -3.96490898e-05  -4.03065529e-05 ...,  -3.36623268e-05
#   -3.28130951e-05  -3.16514225e-05]
# 150000
# 4
# [ -1.33354397e-05  -1.16516800e-05  -1.14817944e-05 ...,   2.89252472e-06
#    6.32039964e-07   4.80212718e-08]
# 150000
# 5
# [  3.45625973e-06   4.25776768e-06   4.99637413e-06 ...,   1.85214787e-05
#    2.14126358e-05   2.05114460e-05]
# 150000
# 6
# [  3.34906435e-06   4.02158499e-06   4.03423166e-06 ...,  -1.43782024e-05
#   -1.46881657e-05  -1.38547726e-05]
# 150000
# 7
# [  9.14939213e-06   9.23983955e-06   8.45698738e-06 ...,   1.76012838e-06
#    5.59717369e-06   8.15587902e-06]
# 150000
# 8
# [  1.18930229e-04   1.18507454e-04   1.16160332e-04 ...,  -2.91754093e-05
# ...
